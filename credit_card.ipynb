# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv(r'C:\Project\credit_card_fraud\creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284294 entries, 0 to 284293
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284294 non-null  float64
#  1   V1      284294 non-null  float64
#  2   V2      284294 non-null  float64
#  3   V3      284294 non-null  float64
#  4   V4      284294 non-null  float64
#  5   V5      284294 non-null  float64
#  6   V6      284294 non-null  float64
#  7   V7      284294 non-null  float64
#  8   V8      284294 non-null  float64
#  9   V9      284294 non-null  float64
#  10  V10     284294 non-null  float64
#  11  V11     284294 non-null  float64
#  12  V12     284294 non-null  float64
#  13  V13     284294 non-null  float64
#  14  V14     284294 non-null  float64
#  15  V15     284294 non-null  float64
#  16  V16     284294 non-null  float64
#  17  V17     284294 non-null  float64
#  18  V18     284294 non-null  float64
#  19  V19     284294 non-null  float64
#  20  V20     284294 non-null  float64
#  21  V21     284294 non-null  float64
#  22  V22     284294 non-null  float64
#  23  V23     284294 non-null  float64
#  24  V24     284294 non-null  float64
#  25  V25     284294 non-null  float64
#  26  V26     284294 non-null  float64
#  27  V27     284294 non-null  float64
#  28  V28     284294 non-null  float64
#  29  Amount  284294 non-null  float64
#  30  Class   284294 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.2 MB

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    283802
# 1       492
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (283802, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    283802.000000
# mean         88.358715
# std         250.283041
# min           0.000000
# 25%           5.690000
# 50%          22.000000
# 75%          77.080000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95007.306929  0.009129 -0.007057  0.010590 -0.007873  0.005677
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002587  0.009455 -0.000972  0.004319  ... -0.000730 -0.001178
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.000364  0.000156  0.000114 -0.000232 -0.000278 -0.000402 -0.000184
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.358715
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95608.008130 -0.022540  0.098942  0.031796  0.037224  0.013308
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.039887  0.085930  0.015241  0.060732  ...  0.041895 -0.021249
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.049365  0.003670  0.015685 -0.019239 -0.012075  0.011502  0.009747
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       93.003882
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x = new_dataset.drop(columns='Class', axis = 1)
y = new_dataset['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LogisticRegression(solver='saga', max_iter=1000)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %%
x_train_prediction = model.predict(x_train_scaled)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  0.9542566709021602

# %%
x_test_prediction = model.predict(x_test_scaled)
testing_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy on Testing data: ', testing_data_accuracy)
# Out:
# Accuracy on Testing data:  0.934010152284264
