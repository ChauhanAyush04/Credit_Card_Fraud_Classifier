# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv(r'C:\Project\credit_card_fraud\creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.isnull().sum()
# Out:
# Time          0
# V1            0
# V2            0
# V3            0
# V4            0
# V5            0
# V6            0
# V7            0
# V8            0
# V9            0
# V10           0
# V11           0
# V12           0
# V13           0
# V14           0
# V15           0
# V16           0
# V17           0
# V18           0
# V19           0
# V20           0
# V21           0
# V22           0
# V23           0
# V24           0
# V25           0
# V26           0
# V27           0
# V28           0
# Amount        0
# Class     92385
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    176750
# 1.0       361
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (176750, 31)
# (361, 31)

# %%
legit.Amount.describe()
# Out:
# count    176750.000000
# mean         89.151864
# std         248.664151
# min           0.000000
# 25%           5.990000
# 50%          22.820000
# 75%          79.000000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     361.000000
# mean      115.730028
# std       249.046690
# min         0.000000
# 25%         1.000000
# 50%        11.390000
# 75%       104.030000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    63827.332696 -0.145410  0.011660  0.463387  0.090289 -0.158033
# 1.0    56932.257618 -6.028143  4.387258 -7.974045  4.879641 -4.377635
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.060648 -0.062020  0.027742  0.010842  ...  0.027984 -0.025909
# 1.0   -1.439800 -7.006817  0.747079 -2.864495  ...  0.413666  0.800406
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.076243 -0.020615  0.005726  0.082194  0.012771  0.000961  0.001863
# 1.0   -0.019488 -0.042725 -0.074686  0.081219  0.032080  0.177250  0.052305
#
#            Amount
# Class
# 0.0     89.151864
# 1.0    115.730028
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=361)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    361
# 1.0    361
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    62261.592798 -0.088577 -0.086351  0.523020  0.074643 -0.097536
# 1.0    56932.257618 -6.028143  4.387258 -7.974045  4.879641 -4.377635
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.097402  0.018918 -0.047576 -0.022671  ...  0.013029  0.042436
# 1.0   -1.439800 -7.006817  0.747079 -2.864495  ...  0.413666  0.800406
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.072118 -0.012366  0.030958  0.097744  0.034975 -0.039109 -0.017693
# 1.0   -0.019488 -0.042725 -0.074686  0.081219  0.032080  0.177250  0.052305
#
#            Amount
# Class
# 0.0    100.962161
# 1.0    115.730028
#
# [2 rows x 30 columns]

# %%
x = new_dataset.drop(columns='Class', axis = 1)
y = new_dataset['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LogisticRegression(solver='saga', max_iter=1000)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %%
x_train_prediction = model.predict(x_train_scaled)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  0.9601386481802426

# %%
x_test_prediction = model.predict(x_test_scaled)
testing_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy on Testing data: ', testing_data_accuracy)
# Out:
# Accuracy on Testing data:  0.9655172413793104
