# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv(r'C:\Project\credit_card_fraud\creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273084 entries, 0 to 273083
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    273084 non-null  float64
#  1   V1      273084 non-null  float64
#  2   V2      273084 non-null  float64
#  3   V3      273084 non-null  float64
#  4   V4      273084 non-null  float64
#  5   V5      273084 non-null  float64
#  6   V6      273084 non-null  float64
#  7   V7      273084 non-null  float64
#  8   V8      273084 non-null  float64
#  9   V9      273084 non-null  float64
#  10  V10     273084 non-null  float64
#  11  V11     273084 non-null  float64
#  12  V12     273084 non-null  float64
#  13  V13     273084 non-null  float64
#  14  V14     273084 non-null  float64
#  15  V15     273084 non-null  float64
#  16  V16     273084 non-null  float64
#  17  V17     273084 non-null  float64
#  18  V18     273084 non-null  float64
#  19  V19     273084 non-null  float64
#  20  V20     273084 non-null  float64
#  21  V21     273084 non-null  float64
#  22  V22     273084 non-null  float64
#  23  V23     273084 non-null  float64
#  24  V24     273084 non-null  float64
#  25  V25     273084 non-null  float64
#  26  V26     273084 non-null  float64
#  27  V27     273084 non-null  float64
#  28  V28     273084 non-null  float64
#  29  Amount  273084 non-null  float64
#  30  Class   273084 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 64.6 MB

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    272602
# 1       482
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (272602, 31)
# (482, 31)

# %%
legit.Amount.describe()
# Out:
# count    272602.000000
# mean         89.116220
# std         247.157752
# min           0.000000
# 25%           5.950000
# 50%          22.500000
# 75%          78.250000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     482.000000
# mean      121.076307
# std       257.478999
# min         0.000000
# 25%         1.000000
# 50%         8.770000
# 75%       104.615000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92016.626147  0.001854 -0.016910  0.041438 -0.001226 -0.006239
# 1      78944.875519 -4.829715  3.701803 -7.115391  4.595626 -3.232056
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.007949  0.003752 -0.000960  0.004370  ...  0.000260 -0.001401
# 1     -1.400979 -5.647874  0.612329 -2.613791  ...  0.369746  0.735548
#
#             V22       V23       V24       V25       V26      V27       V28  \
# Class
# 0     -0.002618 -0.001165  0.001053  0.005845  0.000138 -0.00065  0.000315
# 1      0.003915 -0.051588 -0.110921  0.047685  0.048458  0.16382  0.074354
#
#            Amount
# Class
# 0       89.116220
# 1      121.076307
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=482)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    482
# 1    482
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      89502.614108 -0.021151 -0.070629  0.090986  0.006553 -0.032134
# 1      78944.875519 -4.829715  3.701803 -7.115391  4.595626 -3.232056
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.069374  0.004817  0.016917  0.041768  ... -0.028124 -0.015540
# 1     -1.400979 -5.647874  0.612329 -2.613791  ...  0.369746  0.735548
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000533 -0.024958 -0.007633  0.019718 -0.053944  0.027618  0.023228
# 1      0.003915 -0.051588 -0.110921  0.047685  0.048458  0.163820  0.074354
#
#            Amount
# Class
# 0       90.223133
# 1      121.076307
#
# [2 rows x 30 columns]

# %%
x = new_dataset.drop(columns='Class', axis = 1)
y = new_dataset['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LogisticRegression(solver='saga', max_iter=1000)
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %%
x_train_prediction = model.predict(x_train_scaled)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  0.953307392996109

# %%
x_test_prediction = model.predict(x_test_scaled)
testing_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy on Testing data: ', testing_data_accuracy)
# Out:
# Accuracy on Testing data:  0.9533678756476683
